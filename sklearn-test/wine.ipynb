# %% [markdown]
# 🧪 Mini-projet : Prédire le type de vin à partir de ses propriétés chimiques (Wine dataset)

# %% [markdown]
# l'objectif ici est de creer une pipeline de classifiction pour predire la classifiquation du vin a partir de ces 13 propriété chimiques

# %%
from sklearn.datasets import load_wine
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.pipeline import Pipeline 
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# je vais essayer de tester different algrotihme pour voir lequel pourras produire un modele performant

# %% [markdown]
# sample of the dataset :

# %%
ds = load_wine()
df = pd.DataFrame(ds.data, columns= ds.feature_names )
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
df.corr()
##les donnes ne sont pas trop correlee entr elles
# Out:
#                                alcohol  malic_acid       ash  \
# alcohol                       1.000000    0.094397  0.211545
# malic_acid                    0.094397    1.000000  0.164045
# ash                           0.211545    0.164045  1.000000
# alcalinity_of_ash            -0.310235    0.288500  0.443367
# magnesium                     0.270798   -0.054575  0.286587
# total_phenols                 0.289101   -0.335167  0.128980
# flavanoids                    0.236815   -0.411007  0.115077
# nonflavanoid_phenols         -0.155929    0.292977  0.186230
# proanthocyanins               0.136698   -0.220746  0.009652
# color_intensity               0.546364    0.248985  0.258887
# hue                          -0.071747   -0.561296 -0.074667
# od280/od315_of_diluted_wines  0.072343   -0.368710  0.003911
# proline                       0.643720   -0.192011  0.223626
#
#                               alcalinity_of_ash  magnesium  total_phenols  \
# alcohol                               -0.310235   0.270798       0.289101
# malic_acid                             0.288500  -0.054575      -0.335167
# ash                                    0.443367   0.286587       0.128980
# alcalinity_of_ash                      1.000000  -0.083333      -0.321113
# magnesium                             -0.083333   1.000000       0.214401
# total_phenols                         -0.321113   0.214401       1.000000
# flavanoids                            -0.351370   0.195784       0.864564
# nonflavanoid_phenols                   0.361922  -0.256294      -0.449935
# proanthocyanins                       -0.197327   0.236441       0.612413
# color_intensity                        0.018732   0.199950      -0.055136
# hue                                   -0.273955   0.055398       0.433681
# od280/od315_of_diluted_wines          -0.276769   0.066004       0.699949
# proline                               -0.440597   0.393351       0.498115
#
#                               flavanoids  nonflavanoid_phenols  \
# alcohol                         0.236815             -0.155929
# malic_acid                     -0.411007              0.292977
# ash                             0.115077              0.186230
# alcalinity_of_ash              -0.351370              0.361922
# magnesium                       0.195784             -0.256294
# total_phenols                   0.864564             -0.449935
# flavanoids                      1.000000             -0.537900
# nonflavanoid_phenols           -0.537900              1.000000
# proanthocyanins                 0.652692             -0.365845
# color_intensity                -0.172379              0.139057
# hue                             0.543479             -0.262640
# od280/od315_of_diluted_wines    0.787194             -0.503270
# proline                         0.494193             -0.311385
#
#                               proanthocyanins  color_intensity       hue  \
# alcohol                              0.136698         0.546364 -0.071747
# malic_acid                          -0.220746         0.248985 -0.561296
# ash                                  0.009652         0.258887 -0.074667
# alcalinity_of_ash                   -0.197327         0.018732 -0.273955
# magnesium                            0.236441         0.199950  0.055398
# total_phenols                        0.612413        -0.055136  0.433681
# flavanoids                           0.652692        -0.172379  0.543479
# nonflavanoid_phenols                -0.365845         0.139057 -0.262640
# proanthocyanins                      1.000000        -0.025250  0.295544
# color_intensity                     -0.025250         1.000000 -0.521813
# hue                                  0.295544        -0.521813  1.000000
# od280/od315_of_diluted_wines         0.519067        -0.428815  0.565468
# proline                              0.330417         0.316100  0.236183
#
#                               od280/od315_of_diluted_wines   proline
# alcohol                                           0.072343  0.643720
# malic_acid                                       -0.368710 -0.192011
# ash                                               0.003911  0.223626
# alcalinity_of_ash                                -0.276769 -0.440597
# magnesium                                         0.066004  0.393351
# total_phenols                                     0.699949  0.498115
# flavanoids                                        0.787194  0.494193
# nonflavanoid_phenols                             -0.503270 -0.311385
# proanthocyanins                                   0.519067  0.330417
# color_intensity                                  -0.428815  0.316100
# hue                                               0.565468  0.236183
# od280/od315_of_diluted_wines                      1.000000  0.312761
# proline                                           0.312761  1.000000

# %% [markdown]
# on va creer la pipeline ou on va scaler les atributes avec les quantiles et puis je vais ajouter les modeles ave les parametres

# %%
X, y = ds['data'], ds['target']
Xtrain, Xtest, ytrain , ytest =train_test_split(X, y ,test_size= 0.3, random_state=42)
pcacomponent = 3
pca = PCA(n_components= pcacomponent)

pipe =  Pipeline(
    [('scale', QuantileTransformer()),
     ('model', RandomForestClassifier())]
)
#pipeline de base
#je fais le paramdgrid
paragrid= [
    {"model": [RandomForestClassifier(random_state=42)],
    "scale": [StandardScaler()],
    "model__n_estimators": [10,20,30,50,60,70,100,150] },

    {"model": [RandomForestClassifier(random_state=42)],
    "scale": [QuantileTransformer()],
    "model__n_estimators": [10,20,30,50,60,70,100,150] },

    {"model": [GradientBoostingClassifier(random_state=42)],
    "scale": [QuantileTransformer()],
    "model__n_estimators": [10,20,30,50,60,70,100,150] },
    {"model": [KNeighborsClassifier()],
    "scale": [QuantileTransformer()],
    "model__n_neighbors": [10,20,30] },
    {"scale": [QuantileTransformer()],
     "model": [MLPClassifier(random_state=42)],
    
    "model__hidden_layer_sizes": [(3,),(10,),(15,),(25,),(50)] }
]

# %%
modsearch= GridSearchCV(
    pipe,
    param_grid= paragrid,
    cv=8,
    n_jobs=-1 
)
modsearch.fit(Xtrain, ytrain)
# Out:
# GridSearchCV(cv=8,
#              estimator=Pipeline(steps=[('scale', QuantileTransformer()),
#                                        ('model', RandomForestClassifier())]),
#              n_jobs=-1,
#              param_grid=[{'model': [RandomForestClassifier(random_state=42)],
#                           'model__n_estimators': [10, 20, 30, 50, 60, 70, 100,
#                                                   150],
#                           'scale': [StandardScaler()]},
#                          {'model': [RandomForestClassifier(random_state=42)],
#                           'model__n_estimators': [10, 20, 30, 50,...
#                          {'model': [GradientBoostingClassifier(random_state=42)],
#                           'model__n_estimators': [10, 20, 30, 50, 60, 70, 100,
#                                                   150],
#                           'scale': [QuantileTransformer()]},
#                          {'model': [KNeighborsClassifier()],
#                           'model__n_neighbors': [10, 20, 30],
#                           'scale': [QuantileTransformer()]},
#                          {'model': [MLPClassifier(random_state=42)],
#                           'model__hidden_layer_sizes': [(3,), (10,), (15,),
#                                                         (25,), 50],
#                           'scale': [QuantileTransformer()]}])

# %%
dfresult= pd.DataFrame(modsearch.cv_results_)
print(modsearch.best_estimator_)
dfresult
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('model',
#                  RandomForestClassifier(n_estimators=10, random_state=42))])
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.012464      0.000660         0.001067        0.000531
# 1        0.024466      0.005321         0.002030        0.000512
# 2        0.035184      0.003368         0.002378        0.000698
# 3        0.054964      0.004863         0.003714        0.001913
# 4        0.062532      0.001806         0.003684        0.000903
# 5        0.079327      0.009064         0.005011        0.001428
# 6        0.118248      0.008865         0.006941        0.002485
# 7        0.160118      0.012143         0.007656        0.001493
# 8        0.014052      0.001277         0.002007        0.001003
# 9        0.024886      0.001044         0.002268        0.000451
# 10       0.035235      0.003259         0.003258        0.001468
# 11       0.054537      0.002281         0.004635        0.000755
# 12       0.068361      0.003524         0.004338        0.001164
# 13       0.080201      0.009979         0.004750        0.000679
# 14       0.104821      0.004764         0.005078        0.000766
# 15       0.160822      0.009298         0.008284        0.000386
# 16       0.034132      0.001481         0.001505        0.000869
# 17       0.063958      0.002123         0.001642        0.000688
# 18       0.099652      0.006381         0.001380        0.000861
# 19       0.176701      0.022244         0.002825        0.001036
# 20       0.199725      0.023313         0.001552        0.000740
# 21       0.219255      0.010481         0.002137        0.000233
# 22       0.295921      0.043240         0.001287        0.000755
# 23       0.360780      0.111804         0.003242        0.004949
# 24       0.004588      0.002457         0.003378        0.001172
# 25       0.003337      0.000892         0.003006        0.001496
# 26       0.004025      0.000998         0.003170        0.001187
# 27       0.056699      0.008191         0.002519        0.001210
# 28       0.083279      0.023414         0.001252        0.000435
# 29       0.073042      0.018642         0.001112        0.001050
# 30       0.060874      0.005405         0.001128        0.000929
# 31       0.064039      0.004187         0.000709        0.000658
#
#                                     param_model  param_model__n_estimators  \
# 0       RandomForestClassifier(random_state=42)                       10.0
# 1       RandomForestClassifier(random_state=42)                       20.0
# 2       RandomForestClassifier(random_state=42)                       30.0
# 3       RandomForestClassifier(random_state=42)                       50.0
# 4       RandomForestClassifier(random_state=42)                       60.0
# 5       RandomForestClassifier(random_state=42)                       70.0
# 6       RandomForestClassifier(random_state=42)                      100.0
# 7       RandomForestClassifier(random_state=42)                      150.0
# 8       RandomForestClassifier(random_state=42)                       10.0
# 9       RandomForestClassifier(random_state=42)                       20.0
# 10      RandomForestClassifier(random_state=42)                       30.0
# 11      RandomForestClassifier(random_state=42)                       50.0
# 12      RandomForestClassifier(random_state=42)                       60.0
# 13      RandomForestClassifier(random_state=42)                       70.0
# 14      RandomForestClassifier(random_state=42)                      100.0
# 15      RandomForestClassifier(random_state=42)                      150.0
# 16  GradientBoostingClassifier(random_state=42)                       10.0
# 17  GradientBoostingClassifier(random_state=42)                       20.0
# 18  GradientBoostingClassifier(random_state=42)                       30.0
# 19  GradientBoostingClassifier(random_state=42)                       50.0
# 20  GradientBoostingClassifier(random_state=42)                       60.0
# 21  GradientBoostingClassifier(random_state=42)                       70.0
# 22  GradientBoostingClassifier(random_state=42)                      100.0
# 23  GradientBoostingClassifier(random_state=42)                      150.0
# 24                       KNeighborsClassifier()                        NaN
# 25                       KNeighborsClassifier()                        NaN
# 26                       KNeighborsClassifier()                        NaN
# 27               MLPClassifier(random_state=42)                        NaN
# 28               MLPClassifier(random_state=42)                        NaN
# 29               MLPClassifier(random_state=42)                        NaN
# 30               MLPClassifier(random_state=42)                        NaN
# 31               MLPClassifier(random_state=42)                        NaN
#
#               param_scale  param_model__n_neighbors  \
# 0        StandardScaler()                       NaN
# 1        StandardScaler()                       NaN
# 2        StandardScaler()                       NaN
# 3        StandardScaler()                       NaN
# 4        StandardScaler()                       NaN
# 5        StandardScaler()                       NaN
# 6        StandardScaler()                       NaN
# 7        StandardScaler()                       NaN
# 8   QuantileTransformer()                       NaN
# 9   QuantileTransformer()                       NaN
# 10  QuantileTransformer()                       NaN
# 11  QuantileTransformer()                       NaN
# 12  QuantileTransformer()                       NaN
# 13  QuantileTransformer()                       NaN
# 14  QuantileTransformer()                       NaN
# 15  QuantileTransformer()                       NaN
# 16  QuantileTransformer()                       NaN
# 17  QuantileTransformer()                       NaN
# 18  QuantileTransformer()                       NaN
# 19  QuantileTransformer()                       NaN
# 20  QuantileTransformer()                       NaN
# 21  QuantileTransformer()                       NaN
# 22  QuantileTransformer()                       NaN
# 23  QuantileTransformer()                       NaN
# 24  QuantileTransformer()                      10.0
# 25  QuantileTransformer()                      20.0
# 26  QuantileTransformer()                      30.0
# 27  QuantileTransformer()                       NaN
# 28  QuantileTransformer()                       NaN
# 29  QuantileTransformer()                       NaN
# 30  QuantileTransformer()                       NaN
# 31  QuantileTransformer()                       NaN
#
#    param_model__hidden_layer_sizes  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             NaN
# 27                            (3,)
# 28                           (10,)
# 29                           (15,)
# 30                           (25,)
# 31                              50
#
#                                                params  ...  split1_test_score  \
# 0   {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 1   {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 2   {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 3   {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 4   {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 5   {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 6   {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 7   {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 8   {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 9   {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 10  {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 11  {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 12  {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 13  {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 14  {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 15  {'model': RandomForestClassifier(random_state=...  ...             1.0000
# 16  {'model': GradientBoostingClassifier(random_st...  ...             0.9375
# 17  {'model': GradientBoostingClassifier(random_st...  ...             0.9375
# 18  {'model': GradientBoostingClassifier(random_st...  ...             0.9375
# 19  {'model': GradientBoostingClassifier(random_st...  ...             0.9375
# 20  {'model': GradientBoostingClassifier(random_st...  ...             0.9375
# 21  {'model': GradientBoostingClassifier(random_st...  ...             0.9375
# 22  {'model': GradientBoostingClassifier(random_st...  ...             0.9375
# 23  {'model': GradientBoostingClassifier(random_st...  ...             0.9375
# 24  {'model': KNeighborsClassifier(), 'model__n_ne...  ...             1.0000
# 25  {'model': KNeighborsClassifier(), 'model__n_ne...  ...             1.0000
# 26  {'model': KNeighborsClassifier(), 'model__n_ne...  ...             1.0000
# 27  {'model': MLPClassifier(random_state=42), 'mod...  ...             0.3750
# 28  {'model': MLPClassifier(random_state=42), 'mod...  ...             0.8750
# 29  {'model': MLPClassifier(random_state=42), 'mod...  ...             1.0000
# 30  {'model': MLPClassifier(random_state=42), 'mod...  ...             0.9375
# 31  {'model': MLPClassifier(random_state=42), 'mod...  ...             1.0000
#
#     split2_test_score  split3_test_score  split4_test_score  \
# 0              0.9375             0.9375           0.933333
# 1              0.9375             0.8750           1.000000
# 2              0.9375             0.8750           1.000000
# 3              0.9375             0.8750           1.000000
# 4              0.9375             0.8750           1.000000
# 5              0.9375             0.8750           1.000000
# 6              0.9375             0.8750           1.000000
# 7              0.9375             0.8750           1.000000
# 8              0.9375             0.9375           0.933333
# 9              0.9375             0.8750           1.000000
# 10             0.9375             0.8750           1.000000
# 11             0.9375             0.8750           1.000000
# 12             0.9375             0.8750           1.000000
# 13             0.9375             0.8750           1.000000
# 14             0.9375             0.8750           1.000000
# 15             0.9375             0.8750           1.000000
# 16             0.8125             0.7500           1.000000
# 17             0.8125             0.7500           1.000000
# 18             0.8125             0.7500           1.000000
# 19             0.8125             0.7500           1.000000
# 20             0.8125             0.7500           1.000000
# 21             0.8125             0.7500           1.000000
# 22             0.8125             0.7500           1.000000
# 23             0.8125             0.8125           1.000000
# 24             0.9375             0.9375           1.000000
# 25             0.9375             0.9375           1.000000
# 26             0.9375             0.9375           1.000000
# 27             0.4375             0.6250           0.466667
# 28             0.8125             0.9375           1.000000
# 29             0.9375             0.9375           0.933333
# 30             0.9375             0.8750           1.000000
# 31             0.9375             0.9375           1.000000
#
#     split5_test_score  split6_test_score  split7_test_score  mean_test_score  \
# 0            1.000000           1.000000           1.000000         0.976042
# 1            0.933333           1.000000           1.000000         0.968229
# 2            0.933333           1.000000           1.000000         0.968229
# 3            0.933333           1.000000           1.000000         0.968229
# 4            0.933333           1.000000           1.000000         0.968229
# 5            0.933333           1.000000           1.000000         0.968229
# 6            0.933333           1.000000           1.000000         0.968229
# 7            0.933333           1.000000           1.000000         0.968229
# 8            0.933333           1.000000           1.000000         0.967708
# 9            0.933333           1.000000           1.000000         0.968229
# 10           0.933333           1.000000           1.000000         0.968229
# 11           0.933333           1.000000           1.000000         0.968229
# 12           0.933333           1.000000           1.000000         0.968229
# 13           0.933333           1.000000           1.000000         0.968229
# 14           0.933333           1.000000           1.000000         0.968229
# 15           0.933333           1.000000           1.000000         0.968229
# 16           0.800000           1.000000           0.866667         0.880208
# 17           0.800000           1.000000           0.866667         0.880208
# 18           0.866667           1.000000           0.933333         0.904687
# 19           0.866667           1.000000           0.866667         0.896354
# 20           0.866667           1.000000           0.866667         0.896354
# 21           0.866667           1.000000           0.866667         0.896354
# 22           0.866667           1.000000           0.866667         0.896354
# 23           0.866667           1.000000           0.933333         0.912500
# 24           0.933333           1.000000           0.933333         0.944271
# 25           0.866667           1.000000           0.866667         0.927604
# 26           0.933333           1.000000           0.933333         0.952083
# 27           0.600000           0.600000           0.600000         0.541146
# 28           0.933333           1.000000           0.933333         0.920833
# 29           1.000000           1.000000           1.000000         0.976042
# 30           0.866667           0.933333           0.933333         0.927604
# 31           0.866667           1.000000           1.000000         0.952083
#
#     std_test_score  rank_test_score
# 0         0.030953                1
# 1         0.044582                3
# 2         0.044582                3
# 3         0.044582                3
# 4         0.044582                3
# 5         0.044582                3
# 6         0.044582                3
# 7         0.044582                3
# 8         0.032325               17
# 9         0.044582                3
# 10        0.044582                3
# 11        0.044582                3
# 12        0.044582                3
# 13        0.044582                3
# 14        0.044582                3
# 15        0.044582                3
# 16        0.086721               30
# 17        0.086721               30
# 18        0.082927               25
# 19        0.082979               26
# 20        0.082979               26
# 21        0.082979               26
# 22        0.082979               26
# 23        0.069908               24
# 24        0.058107               20
# 25        0.067634               21
# 26        0.041771               18
# 27        0.092431               32
# 28        0.060273               23
# 29        0.030953                1
# 30        0.038861               21
# 31        0.053441               18
#
# [32 rows x 21 columns]

# %%
# plotter les resultat 
# Convertir param_model en string pour l'affichage
dfresult['model_name'] = dfresult['param_model'].astype(str)

# Créer une figure
plt.figure(figsize=(12, 6))

# Créer une colonne 'param_value' selon le modèle
def get_param_value(row):
    if 'RandomForest' in row['model_name']:
        return row.get('param_model__n_estimators', None)
    elif 'GradientBoosting' in row['model_name']:
        return row.get('param_model__n_estimators', None)
    elif 'KNeighbors' in row['model_name']:
        return row.get('param_model__n_neighbors', None)
    elif 'MLPClassifier' in row['model_name']:
        return row.get('param_model__hidden_layer_sizes', None)
    else:
        return None

dfresult['param_value'] = dfresult.apply(get_param_value, axis=1)

# Nettoyage des valeurs de type tuple pour affichage
dfresult['param_value'] = dfresult['param_value'].apply(lambda x: x if not isinstance(x, tuple) else x[0])

# Supprimer les lignes sans param_value (ex : si vide)
df_filtered = dfresult.dropna(subset=['param_value'])

# Tracer l'histogramme groupé
sns.barplot(
    data=df_filtered,
    x='param_value',
    y='mean_test_score',
    hue='model_name'
)

plt.title('Performance moyenne par modèle et valeur de paramètre clé')
plt.xlabel('Valeur du paramètre (ex: n_estimators, n_neighbors, etc.)')
plt.ylabel('Score moyen en validation croisée')
plt.legend(title='Modèle', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
ypredicted= modsearch.predict(Xtest)
print(accuracy_score(y_true=ytest, y_pred= ypredicted))
print(confusion_matrix(y_true=ytest, y_pred= ypredicted))
# Out:
# 0.9259259259259259
# [[19  0  0]
#  [ 2 18  1]
#  [ 0  1 13]]
